# %%
print("Fake News Detection Project")
# Out:
# Fake News Detection Project

# %%
# !pip install pandas scikit-learn matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.7 MB 12.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.7 MB 16.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 16.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------------------ --------------------- 3.7/8.0 MB 18.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 16.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------- ----------------------------- 2.1/8.1 MB 11.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.1 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.7 MB/s  0:00:00
# ...
